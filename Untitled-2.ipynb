# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data= pd.read_csv("C:/Users/Indan/Downloads/archive (4)/Impact_of_Mobile_Phone_on_Students_Health.csv")

# %%
data
# Out:
#        Names    Age Gender  Mobile Phone  Mobile Operating System   \
# 0        Ali  21-25    Male           Yes                  Android
# 1      Bilal  21-25    Male           Yes                  Android
# 2     Hammad  21-25    Male           Yes                      IOS
# 3   Abdullah  21-25    Male           Yes                  Android
# 4      Waqar  21-25    Male           Yes                      IOS
# ..       ...    ...     ...           ...                      ...
# 95    Zahoor  21-25    Male           Yes                      IOS
# 96    Hafeez  16-20    Male           Yes                  Android
# 97     Babar  16-20    Male           Yes                  Android
# 98    Rizwan  16-20    Male           Yes                  Android
# 99     Lubna  21-25  Female           Yes                  Android
#
#    Mobile phone use for education Mobile phone activities  \
# 0                       Sometimes            Social Media
# ...

# %%
data.shape
# Out:
# (100, 20)

# %%
data.head()
# Out:
#       Names    Age Gender  Mobile Phone  Mobile Operating System   \
# 0       Ali  21-25    Male           Yes                  Android
# 1     Bilal  21-25    Male           Yes                  Android
# 2    Hammad  21-25    Male           Yes                      IOS
# 3  Abdullah  21-25    Male           Yes                  Android
# 4     Waqar  21-25    Male           Yes                      IOS
#
#   Mobile phone use for education Mobile phone activities Helpful for studying  \
# 0                      Sometimes            Social Media                  Yes
# 1                      Sometimes            Social Media                  Yes
# 2                      Sometimes            All of these                  Yes
# 3                     Frequently            All of these                  Yes
# 4                     Frequently            All of these                  Yes
#
#      Educational Apps Daily usages Performance impact      Usage distraction  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 20 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Names                           100 non-null    object
#  1   Age                             100 non-null    object
#  2   Gender                          100 non-null    object
#  3   Mobile Phone                    100 non-null    object
#  4   Mobile Operating System         100 non-null    object
#  5   Mobile phone use for education  98 non-null     object
#  6   Mobile phone activities         99 non-null     object
#  7   Helpful for studying            98 non-null     object
#  8   Educational Apps                98 non-null     object
#  9   Daily usages                    99 non-null     object
#  10  Performance impact              98 non-null     object
#  11  Usage distraction               98 non-null     object
# ...

# %%
data.drop(['Useful features','Symptom frequency'],axis=1,inplace=True)

# %%
data
# Out:
#        Names    Age Gender  Mobile Phone  Mobile Operating System   \
# 0        Ali  21-25    Male           Yes                  Android
# 1      Bilal  21-25    Male           Yes                  Android
# 2     Hammad  21-25    Male           Yes                      IOS
# 3   Abdullah  21-25    Male           Yes                  Android
# 4      Waqar  21-25    Male           Yes                      IOS
# ..       ...    ...     ...           ...                      ...
# 95    Zahoor  21-25    Male           Yes                      IOS
# 96    Hafeez  16-20    Male           Yes                  Android
# 97     Babar  16-20    Male           Yes                  Android
# 98    Rizwan  16-20    Male           Yes                  Android
# 99     Lubna  21-25  Female           Yes                  Android
#
#    Mobile phone use for education Mobile phone activities  \
# 0                       Sometimes            Social Media
# ...

# %%
pd.isnull(data).sum()
# Out:
# Names                             0
# Age                               0
# Gender                            0
# Mobile Phone                      0
# Mobile Operating System           0
# Mobile phone use for education    2
# Mobile phone activities           1
# Helpful for studying              2
# Educational Apps                  2
# Daily usages                      1
# Performance impact                2
# Usage distraction                 2
# Attention span                    1
# Health Risks                      2
# Beneficial subject                1
# Usage symptoms                    2
# Health precautions                1
# Health rating                     1
# dtype: int64

# %%
pd.isnull(data)
# Out:
#     Names    Age  Gender   Mobile Phone   Mobile Operating System   \
# 0   False  False    False          False                     False
# 1   False  False    False          False                     False
# 2   False  False    False          False                     False
# 3   False  False    False          False                     False
# 4   False  False    False          False                     False
# ..    ...    ...      ...            ...                       ...
# 95  False  False    False          False                     False
# 96  False  False    False          False                     False
# 97  False  False    False          False                     False
# 98  False  False    False          False                     False
# 99  False  False    False          False                     False
#
#     Mobile phone use for education  Mobile phone activities  \
# 0                            False                    False
# ...

# %%
df =[['madhav',12],['Gopi',17],['Keshav',15]]
data=pd.DataFrame(df,column=['Names','Age'])
data
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 df =[['madhav',12],['Gopi',17],['Keshav',15]]
# ----> 2 data=pd.DataFrame(df,column=['Names','Age'])
#       3 data
#
# TypeError: DataFrame.__init__() got an unexpected keyword argument 'column'

# %%
data.rename(columns={'Mobile phone use for education':'Education purchues'})
# Out:
#        Names    Age Gender  Mobile Phone  Mobile Operating System   \
# 0        Ali  21-25    Male           Yes                  Android
# 1      Bilal  21-25    Male           Yes                  Android
# 2     Hammad  21-25    Male           Yes                      IOS
# 3   Abdullah  21-25    Male           Yes                  Android
# 4      Waqar  21-25    Male           Yes                      IOS
# ..       ...    ...     ...           ...                      ...
# 95    Zahoor  21-25    Male           Yes                      IOS
# 96    Hafeez  16-20    Male           Yes                  Android
# 97     Babar  16-20    Male           Yes                  Android
# 98    Rizwan  16-20    Male           Yes                  Android
# 99     Lubna  21-25  Female           Yes                  Android
#
#    Education purchues Mobile phone activities Helpful for studying  \
# 0           Sometimes            Social Media                  Yes
# ...

# %%
data.describe()
# Out:
#        Names    Age Gender  Mobile Phone  Mobile Operating System   \
# count    100    100     100           100                      100
# unique   100      4       2             1                        2
# top      Ali  21-25    Male           Yes                  Android
# freq       1     72      81           100                       81
#
#        Mobile phone use for education Mobile phone activities  \
# count                              98                      99
# unique                              4                       7
# top                         Sometimes            All of these
# freq                               53                      59
#
#        Helpful for studying    Educational Apps Daily usages  \
# count                    98                  98           99
# unique                    2                   4            4
# top                     Yes  Educational Videos    4-6 hours
# freq                     94                  54           40
#
# ...

# %%
data.columns
# Out:
# Index(['Names', 'Age', 'Gender ', 'Mobile Phone ', 'Mobile Operating System ',
#        'Mobile phone use for education', 'Mobile phone activities',
#        'Helpful for studying', 'Educational Apps', 'Daily usages',
#        'Performance impact', 'Usage distraction', 'Attention span',
#        'Health Risks', 'Beneficial subject', 'Usage symptoms',
#        'Health precautions', 'Health rating'],
#       dtype='object')

# %%
data.head()
# Out:
#       Names    Age Gender  Mobile Phone  Mobile Operating System   \
# 0       Ali  21-25    Male           Yes                  Android
# 1     Bilal  21-25    Male           Yes                  Android
# 2    Hammad  21-25    Male           Yes                      IOS
# 3  Abdullah  21-25    Male           Yes                  Android
# 4     Waqar  21-25    Male           Yes                      IOS
#
#   Mobile phone use for education Mobile phone activities Helpful for studying  \
# 0                      Sometimes            Social Media                  Yes
# 1                      Sometimes            Social Media                  Yes
# 2                      Sometimes            All of these                  Yes
# 3                     Frequently            All of these                  Yes
# 4                     Frequently            All of these                  Yes
#
#      Educational Apps Daily usages Performance impact      Usage distraction  \
# ...

# %%
data.dropna()
# Out:
#      Names    Age Gender  Mobile Phone  Mobile Operating System   \
# 0      Ali  21-25    Male           Yes                  Android
# 1    Bilal  21-25    Male           Yes                  Android
# 2   Hammad  21-25    Male           Yes                      IOS
# 4    Waqar  21-25    Male           Yes                      IOS
# 5   Aammar  21-25    Male           Yes                  Android
# ..     ...    ...     ...           ...                      ...
# 95  Zahoor  21-25    Male           Yes                      IOS
# 96  Hafeez  16-20    Male           Yes                  Android
# 97   Babar  16-20    Male           Yes                  Android
# 98  Rizwan  16-20    Male           Yes                  Android
# 99   Lubna  21-25  Female           Yes                  Android
#
#    Mobile phone use for education Mobile phone activities  \
# 0                       Sometimes            Social Media
# 1                       Sometimes            Social Media
# ...

# %%
data.rename(columns={'	Mobile Phone':'Phone'})
data
# Out:
#      Names    Age Gender  Mobile Phone  Mobile Operating System   \
# 0      Ali  21-25    Male           Yes                  Android
# 1    Bilal  21-25    Male           Yes                  Android
# 2   Hammad  21-25    Male           Yes                      IOS
# 4    Waqar  21-25    Male           Yes                      IOS
# 5   Aammar  21-25    Male           Yes                  Android
# ..     ...    ...     ...           ...                      ...
# 95  Zahoor  21-25    Male           Yes                      IOS
# 96  Hafeez  16-20    Male           Yes                  Android
# 97   Babar  16-20    Male           Yes                  Android
# 98  Rizwan  16-20    Male           Yes                  Android
# 99   Lubna  21-25  Female           Yes                  Android
#
#    Mobile phone use for education Mobile phone activities  \
# 0                       Sometimes            Social Media
# 1                       Sometimes            Social Media
# ...

# %%
data.columns
# Out:
# Index(['Names', 'Age', 'Gender ', 'Mobile Phone ', 'Mobile Operating System ',
#        'Mobile phone use for education', 'Mobile phone activities',
#        'Helpful for studying', 'Educational Apps', 'Daily usages',
#        'Performance impact', 'Usage distraction', 'Attention span',
#        'Health Risks', 'Beneficial subject', 'Usage symptoms',
#        'Health precautions', 'Health rating'],
#       dtype='object')

# %%
data.describe()
# Out:
#        Names    Age Gender  Mobile Phone  Mobile Operating System   \
# count     92     92      92            92                       92
# unique    92      4       2             1                        2
# top      Ali  21-25    Male           Yes                  Android
# freq       1     69      74            92                       73
#
#        Mobile phone use for education Mobile phone activities  \
# count                              92                      92
# unique                              4                       7
# top                         Sometimes            All of these
# freq                               52                      57
#
#        Helpful for studying    Educational Apps Daily usages  \
# count                    92                  92           92
# unique                    2                   4            4
# top                     Yes  Educational Videos    4-6 hours
# freq                     88                  53           39
#
# ...

# %%
data[['Names','Age',]].describe()
# Out:
#        Names    Age
# count     92     92
# unique    92      4
# top      Ali  21-25
# freq       1     69

# %%
data.columns
# Out:
# Index(['Names', 'Age', 'Gender ', 'Mobile Phone ', 'Mobile Operating System ',
#        'Mobile phone use for education', 'Mobile phone activities',
#        'Helpful for studying', 'Educational Apps', 'Daily usages',
#        'Performance impact', 'Usage distraction', 'Attention span',
#        'Health Risks', 'Beneficial subject', 'Usage symptoms',
#        'Health precautions', 'Health rating'],
#       dtype='object')

# %%
sns.catplot('Age')

# %%
sns.countplot('Gender')
# Out:
# <Axes: xlabel='count'>

# %%
ax=sns.countplot('Age')
for bars in ax.containers:
    ax.bar_label(bars)
