# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df=pd.read_csv("C:/Users/Indan/Downloads/archive (6)/weather_classification_data.csv")

# %%
df
# Out:
#        Temperature  Humidity  Wind Speed  Precipitation (%)    Cloud Cover  \
# 0             14.0        73         9.5               82.0  partly cloudy
# 1             39.0        96         8.5               71.0  partly cloudy
# 2             30.0        64         7.0               16.0          clear
# 3             38.0        83         1.5               82.0          clear
# 4             27.0        74        17.0               66.0       overcast
# ...            ...       ...         ...                ...            ...
# 13195         10.0        74        14.5               71.0       overcast
# 13196         -1.0        76         3.5               23.0         cloudy
# 13197         30.0        77         5.5               28.0       overcast
# 13198          3.0        76        10.0               94.0       overcast
# 13199         -5.0        38         0.0               92.0       overcast
#
# ...

# %%
df.head()
# Out:
#    Temperature  Humidity  Wind Speed  Precipitation (%)    Cloud Cover  \
# 0         14.0        73         9.5               82.0  partly cloudy
# 1         39.0        96         8.5               71.0  partly cloudy
# 2         30.0        64         7.0               16.0          clear
# 3         38.0        83         1.5               82.0          clear
# 4         27.0        74        17.0               66.0       overcast
#
#    Atmospheric Pressure  UV Index  Season  Visibility (km)  Location  \
# 0               1010.82         2  Winter              3.5    inland
# 1               1011.43         7  Spring             10.0    inland
# 2               1018.72         5  Spring              5.5  mountain
# 3               1026.25         7  Spring              1.0   coastal
# 4                990.67         1  Winter              2.5  mountain
#
#   Weather Type
# 0        Rainy
# 1       Cloudy
# 2        Sunny
# 3        Sunny
# 4        Rainy

# %%
df.tail()
# Out:
#        Temperature  Humidity  Wind Speed  Precipitation (%) Cloud Cover  \
# 13195         10.0        74        14.5               71.0    overcast
# 13196         -1.0        76         3.5               23.0      cloudy
# 13197         30.0        77         5.5               28.0    overcast
# 13198          3.0        76        10.0               94.0    overcast
# 13199         -5.0        38         0.0               92.0    overcast
#
#        Atmospheric Pressure  UV Index  Season  Visibility (km)  Location  \
# 13195               1003.15         1  Summer              1.0  mountain
# 13196               1067.23         1  Winter              6.0   coastal
# 13197               1012.69         3  Autumn              9.0   coastal
# 13198                984.27         0  Winter              2.0    inland
# 13199               1015.37         5  Autumn             10.0  mountain
#
#       Weather Type
# 13195        Rainy
# 13196        Snowy
# 13197       Cloudy
# ...

# %%
df.columns
# Out:
# Index(['Temperature', 'Humidity', 'Wind Speed', 'Precipitation (%)',
#        'Cloud Cover', 'Atmospheric Pressure', 'UV Index', 'Season',
#        'Visibility (km)', 'Location', 'Weather Type'],
#       dtype='object')

# %%
df.info
# Out:
# <bound method DataFrame.info of        Temperature  Humidity  Wind Speed  Precipitation (%)    Cloud Cover  \
# 0             14.0        73         9.5               82.0  partly cloudy
# 1             39.0        96         8.5               71.0  partly cloudy
# 2             30.0        64         7.0               16.0          clear
# 3             38.0        83         1.5               82.0          clear
# 4             27.0        74        17.0               66.0       overcast
# ...            ...       ...         ...                ...            ...
# 13195         10.0        74        14.5               71.0       overcast
# 13196         -1.0        76         3.5               23.0         cloudy
# 13197         30.0        77         5.5               28.0       overcast
# 13198          3.0        76        10.0               94.0       overcast
# 13199         -5.0        38         0.0               92.0       overcast
#
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of        Temperature  Humidity  Wind Speed  Precipitation (%)    Cloud Cover  \
# 0             14.0        73         9.5               82.0  partly cloudy
# 1             39.0        96         8.5               71.0  partly cloudy
# 2             30.0        64         7.0               16.0          clear
# 3             38.0        83         1.5               82.0          clear
# 4             27.0        74        17.0               66.0       overcast
# ...            ...       ...         ...                ...            ...
# 13195         10.0        74        14.5               71.0       overcast
# 13196         -1.0        76         3.5               23.0         cloudy
# 13197         30.0        77         5.5               28.0       overcast
# 13198          3.0        76        10.0               94.0       overcast
# 13199         -5.0        38         0.0               92.0       overcast
#
# ...

# %%
df.isnull().sum()
# Out:
# Temperature             0
# Humidity                0
# Wind Speed              0
# Precipitation (%)       0
# Cloud Cover             0
# Atmospheric Pressure    0
# UV Index                0
# Season                  0
# Visibility (km)         0
# Location                0
# Weather Type            0
# dtype: int64

# %%
[features for features in df.columns if df[features].isnull().sum()>1]
# Out:
# []

# %%
sns.heatmap(df.isnull(),yticklables=False,cbar=False,cmap='viridis')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 sns.heatmap(df.isnull(),yticklables=False,cbar=False,cmap='viridis')
#
# File c:\Users\Indan\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\matrix.py:459, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     457 if square:
#     458     ax.set_aspect("equal")
# --> 459 plotter.plot(ax, cbar_ax, kwargs)
#     460 return ax
#
# File c:\Users\Indan\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\matrix.py:306, in _HeatMapper.plot(self, ax, cax, kws)
#     303     kws.setdefault("vmax", self.vmax)
#     305 # Draw the heatmap
# --> 306 mesh = ax.pcolormesh(self.plot_data, cmap=self.cmap, **kws)
#     308 # Set the axis limits
# ...

# %%
df_country=pd.read_csv("C:/Users/Indan/Downloads/archive (4)/county code    country.txt")
df_country.head()
# Out:
#       county code    country
# 0          1           India
# 1      14          Austraila
# 2         13          Africa
# 3            16          USA
# 4         17          Canada

# %%
df.head()
# Out:
#    Temperature  Humidity  Wind Speed  Precipitation (%)    Cloud Cover  \
# 0         14.0        73         9.5               82.0  partly cloudy
# 1         39.0        96         8.5               71.0  partly cloudy
# 2         30.0        64         7.0               16.0          clear
# 3         38.0        83         1.5               82.0          clear
# 4         27.0        74        17.0               66.0       overcast
#
#    Atmospheric Pressure  UV Index  Season  Visibility (km)  Location  \
# 0               1010.82         2  Winter              3.5    inland
# 1               1011.43         7  Spring             10.0    inland
# 2               1018.72         5  Spring              5.5  mountain
# 3               1026.25         7  Spring              1.0   coastal
# 4                990.67         1  Winter              2.5  mountain
#
#   Weather Type
# 0        Rainy
# 1       Cloudy
# 2        Sunny
# 3        Sunny
# 4        Rainy

# %%
inland= df[df.Location=='inland']

# %%
plt.bar(inland['Temperature'],inland['Humidity'])
plt.title('Temperature')
plt.ylable('Humidity')
plt.gcf().set_size_inches(5,5)
plt.xticks(rotation=90)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[61], line 3
#       1 plt.bar(inland['Temperature'],inland['Humidity'])
#       2 plt.title('Temperature')
# ----> 3 plt.ylable('Humidity')
#       4 plt.gcf().set_size_inches(5,5)
#       5 plt.xticks(rotation=90)
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'ylable'
